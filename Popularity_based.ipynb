# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import re

# %% [markdown]
# ## 🖋 Reading Datasets

# %%
movies = pd.read_csv("Datasets/movies.csv")
ratings = pd.read_csv("Datasets/ratings.csv")

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## 🎇 Feature Engineering in Movies Dataset
# - extract Year of movie production as separated Feature by `Extract_Year`
# - removing **`()`** from the Column by `Clean_title()`

# %%
def Extract_Year(String:str):
    try:
        return int(re.findall(pattern=r"(\d+)",string=String)[0])
    except IndexError: 
        return 0

# %%
def clean_title(String:str):
        return re.sub(pattern=r"[(\d+)]",repl="",string=String)

# %%
movies["Year"] = movies.apply(lambda x:Extract_Year(x["title"]),axis=1)

# %%
movies["title"] = movies.apply(lambda x:clean_title(x["title"]),axis=1)

# %% [markdown]
# ## 🟢 Movies dataset after Feature Engineering

# %%
movies.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  Year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# ## ❌ Movies without Production Year

# %%
movies[movies["Year"]==0]
# Out:
#        movieId                                        title  \
# 6423      6546        Km.  - Kilometer Zero Kilómetro cero
# 9815     32743                             Ringu : Bâsudei
# 15036    79607        Millions Game, The Das Millionenspiel
# 25387   123619                           Terrible Joe Moran
# 26284   125571         The Court-Martial of Jackie Robinson
# ...        ...                                          ...
# 62071   207714                       Tales of Found Footage
# 62104   207884                             Enduring Destiny
# 62285   208597  Punk the Capital: Building a Sound Movement
# 62326   208763                 Yosemite: The Fate of Heaven
# 62380   208973          The Falklands War: The Untold Story
#
#                              genres  Year
# 6423                   Comedy|Drama     0
# 9815          Drama|Horror|Thriller     0
# 15036  Action|Drama|Sci-Fi|Thriller     0
# 25387            (no genres listed)     0
# 26284            (no genres listed)     0
# ...                             ...   ...
# 62071            (no genres listed)     0
# 62104            (no genres listed)     0
# 62285                   Documentary     0
# 62326            (no genres listed)     0
# 62380            (no genres listed)     0
#
# [394 rows x 4 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %% [markdown]
# ## 🟢 Now, we can Merge 2 Datasets based on **`movieId`** Column

# %%
df = pd.merge(movies,ratings,on="movieId",how="left")

# %% [markdown]
# ## 👌 Check if there exist any Null Values

# %%
df.isnull().sum()
# Out:
# movieId         0
# title           0
# genres          0
# Year            0
# userId       3376
# rating       3376
# timestamp    3376
# dtype: int64

# %%
df.dropna()
# Out:
#           movieId                     title  \
# 0               1                Toy Story
# 1               1                Toy Story
# 2               1                Toy Story
# 3               1                Toy Story
# 4               1                Toy Story
# ...           ...                       ...
# 25003466   209157                       We
# 25003467   209159       Window of the Soul
# 25003468   209163                Bad Poems
# 25003469   209169             A Girl Thing
# 25003470   209171  Women of Devil's Island
#
#                                                genres  Year    userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy  1995       2.0     3.5
# 1         Adventure|Animation|Children|Comedy|Fantasy  1995       3.0     4.0
# 2         Adventure|Animation|Children|Comedy|Fantasy  1995       4.0     3.0
# 3         Adventure|Animation|Children|Comedy|Fantasy  1995       5.0     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy  1995       8.0     4.0
# ...                                               ...   ...       ...     ...
# 25003466                                        Drama  2018  119571.0     1.5
# 25003467                                  Documentary  2001  115835.0     3.0
# 25003468                                 Comedy|Drama  2018    6964.0     4.5
# 25003469                           (no genres listed)  2001  119571.0     3.0
# 25003470                       Action|Adventure|Drama  1962  119571.0     3.0
#
#              timestamp
# 0         1.141416e+09
# 1         1.439472e+09
# 2         1.573944e+09
# 3         8.586259e+08
# 4         8.904925e+08
# ...                ...
# 25003466  1.574281e+09
# 25003467  1.574281e+09
# 25003468  1.574285e+09
# 25003469  1.574292e+09
# 25003470  1.574292e+09
#
# [25000095 rows x 7 columns]

# %% [markdown]
# ### 👀 Here we begin! We grouped the dataset by **`movieId`** at base to add:
# - **`rating`** Column by aggregate each movie's rates into one value by get **mean** Value
# - **`votes`** Column by base to get number of rates to each movie

# %%
rating = df.groupby(by=["movieId","title","Year"])["rating"].mean().reset_index()

# %%
rating.head()
# Out:
#    movieId                         title  Year    rating
# 0        1                    Toy Story   1995  3.893708
# 1        2                      Jumanji   1995  3.251527
# 2        3             Grumpier Old Men   1995  3.142028
# 3        4            Waiting to Exhale   1995  2.853547
# 4        5  Father of the Bride Part II   1995  3.058434

# %%
vote = df.groupby(by=["movieId","title"])["timestamp"].count().reset_index()

# %%
vote.head()
# Out:
#    movieId                         title  timestamp
# 0        1                    Toy Story       57309
# 1        2                      Jumanji       24228
# 2        3             Grumpier Old Men       11804
# 3        4            Waiting to Exhale        2523
# 4        5  Father of the Bride Part II       11714

# %% [markdown]
# ## 👌 Here We add **`rating`** and **`votes`** Columns to our Dataset

# %%
new_df = pd.merge(left=rating,right=vote,how="left",on=["movieId","title"]).rename(columns={"rating":"Rating","timestamp":"Votes"})

# %%
new_df.head()
# Out:
#    movieId                         title  Year    Rating  Votes
# 0        1                    Toy Story   1995  3.893708  57309
# 1        2                      Jumanji   1995  3.251527  24228
# 2        3             Grumpier Old Men   1995  3.142028  11804
# 3        4            Waiting to Exhale   1995  2.853547   2523
# 4        5  Father of the Bride Part II   1995  3.058434  11714

# %% [markdown]
# ### Here’s equation written **properly as a mathematical formula** 👇
#
#
# ### 📐 Mathematical form
# $$\text{Weighted Rating} = \frac{vR}{v + m} + \frac{mC}{v + m}$$
# Or equivalently (more compact and common in papers):
# $$\text{Weighted Rating}=\frac{vR + mC}{v + m}$$
#
#
# - **v** is the number of votes for the movie;
# - **R** is the average rating of the movie;
# - **m** is the minimum votes required to be listed in the chart;
# - **C** is the mean vote across the whole report.
# Now we find the values of v,m,R,C.
#
# > we Used This equation to get **`Popularity Score`**

# %%
C = new_df["Rating"].mean()
m = new_df["Votes"].quantile(0.9)

# %%
def Weighted_Rating(v:float,R:float):
    return (v * R/ (v + m)) + (m * C / (v + m))

# %%
new_df["Popularity_Score"] = new_df.apply(lambda dataset: Weighted_Rating(v=dataset["Votes"],R=dataset["Rating"]),axis=1)

# %% [markdown]
# ## 🟢 Now, We Sorting Dataset based on **`Popularity Score`**

# %%
top_Ten = new_df.sort_values(by="Popularity_Score",ascending=False,ignore_index=True)
top_Ten[:10]
# Out:
#    movieId                                title  Year    Rating  Votes  \
# 0      318           Shawshank Redemption, The   1994  4.413576  81482
# 1      858                      Godfather, The   1972  4.324336  52498
# 2       50                 Usual Suspects, The   1995  4.284353  55366
# 3     1221             Godfather: Part II, The   1974  4.261759  34188
# 4      527                    Schindler's List   1993  4.247579  60411
# 5   159817                        Planet Earth   2006  4.464797   1747
# 6     2019  Seven Samurai Shichinin no samurai   1954  4.254769  13367
# 7     2959                          Fight Club   1999  4.228311  58773
# 8     1203                           Angry Men     12  4.243014  16569
# 9      904                         Rear Window   1954  4.237948  20162
#
#    Popularity_Score
# 0          4.407590
# 1          4.315685
# 2          4.276409
# 3          4.249184
# 4          4.240515
# 5          4.223983
# 6          4.223314
# 7          4.221170
# 8          4.217760
# 9          4.217204

# %% [markdown]
# ## 💹 Simple Graph To represent most popular Movies based on users Rating

# %%
sns.set_theme(style="whitegrid",context="talk",font_scale=1.1)
plt.figure(figsize=(18, 12))

ax = sns.barplot(x="Popularity_Score",y="title",data=top_Ten[0:10],palette="viridis",hue="Popularity_Score",legend=False)

ax.set_title("Top 10 Most Popular Movies",fontsize=22,weight="bold",pad=20)

ax.set_xlabel("Popularity Score", fontsize=16)
ax.set_ylabel("Movie Title", fontsize=16)

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", padding=6, fontsize=13,weight="bold")
plt.grid(visible=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# <h1 align="center">The End of model 😎</h1>
#
#
# ---
